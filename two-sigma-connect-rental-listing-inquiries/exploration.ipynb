# %%
# %matplotlib inline
import quadkey
import os
import sys
import operator
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import sparse
from sklearn import model_selection, preprocessing, ensemble
from sklearn.metrics import log_loss
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %% [markdown]
# read files

# %%
data_path = "input/"
train_file = data_path + "train.json"
test_file = data_path + "test.json"
train_df = pd.read_json(train_file)
test_df = pd.read_json(test_file)
print(train_df.shape)
print(test_df.shape)
# Out:
# (49352, 15)
# (74659, 14)

# %%
train_df.head()
# Out:
#         bathrooms  bedrooms                       building_id  \
# 10            1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 10000         1.0         2  c5c8a357cba207596b04d1afd1e4f130
# 100004        1.0         1  c3ba40552e2120b0acfc3cb5730bb2aa
# 100007        1.0         1  28d9ad350afeaab8027513a3e52ac8d5
# 100013        1.0         4                                 0
#
#                     created  \
# 10      2016-06-24 07:54:24
# 10000   2016-06-12 12:19:27
# 100004  2016-04-17 03:26:41
# 100007  2016-04-18 02:22:02
# 100013  2016-04-28 01:32:41
#
#                                               description  \
# 10      A Brand New 3 Bedroom 1.5 bath ApartmentEnjoy ...
# 10000
# 100004  Top Top West Village location, beautiful Pre-w...
# 100007  Building Amenities - Garage - Garden - fitness...
# 100013  Beautifully renovated 3 bedroom flex 4 bedroom...
#
#             display_address  \
# 10      Metropolitan Avenue
# 10000       Columbus Avenue
# ...

# %%
train_df.describe()
# Out:
#          bathrooms      bedrooms      latitude    listing_id     longitude  \
# count  49352.00000  49352.000000  49352.000000  4.935200e+04  49352.000000
# mean       1.21218      1.541640     40.741545  7.024055e+06    -73.955716
# std        0.50142      1.115018      0.638535  1.262746e+05      1.177912
# min        0.00000      0.000000      0.000000  6.811957e+06   -118.271000
# 25%        1.00000      1.000000     40.728300  6.915888e+06    -73.991700
# 50%        1.00000      1.000000     40.751800  7.021070e+06    -73.977900
# 75%        1.00000      2.000000     40.774300  7.128733e+06    -73.954800
# max       10.00000      8.000000     44.883500  7.753784e+06      0.000000
#
#               price
# count  4.935200e+04
# mean   3.830174e+03
# std    2.206687e+04
# min    4.300000e+01
# 25%    2.500000e+03
# 50%    3.150000e+03
# 75%    4.100000e+03
# max    4.490000e+06

# %%
sns.distplot(train_df['bathrooms'], kde=False)

# %%
sns.distplot(train_df['bedrooms'], kde=False)

# %%
sns.distplot(train_df['price'], kde=False)

# %%
sns.boxplot(x="bathrooms", y="price", data=train_df, palette="PRGn")

# %%
sns.boxplot(x="bathrooms", y="price", data=train_df[train_df['bathrooms']>1], palette="PRGn")

# %%
sns.boxplot(x="bedrooms", y="price", data=train_df, palette="PRGn")

# %%
sns.boxplot(x="bedrooms", y="price" , data=train_df[train_df['bedrooms']>2], palette="PRGn")

# %%
sns.jointplot("bathrooms", "bedrooms", data=train_df, kind="reg", color="r", size=7)

# %%
# add quadkey
train_df['quadkey_9'] = train_df.apply(lambda row: str(quadkey.from_geo((row['latitude'], row['longitude']), 9)), axis=1)

# %%
train_df.dtypes
# Out:
# bathrooms          float64
# bedrooms             int64
# building_id         object
# created             object
# description         object
# display_address     object
# features            object
# interest_level      object
# latitude           float64
# listing_id           int64
# longitude          float64
# manager_id          object
# photos              object
# price                int64
# street_address      object
# quadkey             object
# quadkey_15          object
# quadkey_9           object
# dtype: object
